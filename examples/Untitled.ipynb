# %%
a = [[1,2,3], [4,5], [6,7]]

# %%
desired = [
    [1,4,6],
    [1,4,7],
    [1,5,6],
    [1,5,7],
    [2,4,6],
    [2,4,7],
    [2,5,6],
    [2,5,7],
    [3,4,6],
    [3,4,7],
    [3,5,6],
    [3,5,7],
]
print(len(desired))
# Out:
# 12

# %%
from itertools import product
out = list(product(*a))
print(out)
print(len(out))
# Out:
# [(1, 4, 6), (1, 4, 7), (1, 5, 6), (1, 5, 7), (2, 4, 6), (2, 4, 7), (2, 5, 6), (2, 5, 7), (3, 4, 6), (3, 4, 7), (3, 5, 6), (3, 5, 7)]
# 12

# %%
b = {'epochs':[10, 20, 30], 'smth': ['hello', 'goodbye'], 'nested':[[],[1,2], ['morning', 'hello']]}

# %%
new =(
        [{key: val} for val in value]
        for key, value in b.items()
    )

# %%
import json
print(json.dumps(list(product(*new)), indent=2))
# Out:
# [
#   [
#     {
#       "epochs": 10
#     },
#     {
#       "smth": "hello"
#     },
#     {
#       "nested": []
#     }
#   ],
#   [
#     {
#       "epochs": 10
#     },
#     {
#       "smth": "hello"
#     },
#     {
#       "nested": [
#         1,
#         2
#       ]
#     }
#   ],
#   [
#     {
#       "epochs": 10
#     },
#     {
#       "smth": "hello"
#     },
#     {
#       "nested": [
#         "morning",
#         "hello"
#       ]
#     }
#   ],
#   [
#     {
#       "epochs": 10
#     },
#     {
#       "smth": "goodbye"
#     },
#     {
#       "nested": []
#     }
#   ],
#   [
#     {
#       "epochs": 10
#     },
#     {
#       "smth": "goodbye"
#     },
#     {
#       "nested": [
#         1,
#         2
#       ]
#     }
#   ],
#   [
#     {
#       "epochs": 10
#     },
#     {
#       "smth": "goodbye"
#     },
#     {
#       "nested": [
#         "morning",
#         "hello"
#       ]
#     }
#   ],
#   [
#     {
#       "epochs": 20
#     },
#     {
# ...
